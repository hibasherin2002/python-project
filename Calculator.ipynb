# %%
from tkinter import *
window = Tk()
window.title("SIMPLE CALCULATOR")
window.geometry('350x200')


def clicked():
    a=entry1.insert(END,num)
    
def clear():
    entry1.delete(0,END)
    
def clear1():
    a = entry1.get()
    length = len(a)
    entry1.delete(length-1,END)
    
def eva():
    equal()
    entry1.insert(END,l)


    



def equal():
    while True:
        global l
        h= entry1.get()
        b=str(h)
        d=eval(b)
        l=('=',d)
        return l
    
    
def repeat():
    try:
        eva()
    except:
        clear()
        entry1.insert(END,'syntax error')
        

        
        
    

entry1= Entry(window,width=33)

entry1.place(x=105,y=15)

btn = Button(window, text="AC",command=clear,width=5,bg='gray',fg='white')
btn.place(x=105,y=50)
btn = Button(window, text="CE",command=clear1,width=5,bg='gray',fg='white')
btn.place(x=158,y=50)
btn = Button(window, text="/",command=lambda:entry1.insert(END,'/'),width=5,bg='gray',fg='white')
btn.place(x=210,y=50)
btn = Button(window, text="%",command=lambda:entry1.insert(END,'/100'),width=5,bg='gray',fg='white')
btn.place(x=262,y=50)
btn = Button(window, text="7",command=lambda:entry1.insert(END,'7'),width=5)
btn.place(x=105,y=80)
btn = Button(window, text="8",command=lambda:entry1.insert(END,'8'),width=5)
btn.place(x=158,y=80)
btn = Button(window, text="9",command=lambda:entry1.insert(END,'9'),width=5)
btn.place(x=210,y=80)
btn = Button(window, text="x",command=lambda:entry1.insert(END,'*'),width=5,bg='gray',fg='white')
btn.place(x=262,y=80)
btn = Button(window, text="4",command=lambda:entry1.insert(END,'4'),width=5)
btn.place(x=105,y=110)
btn = Button(window, text="5",command=lambda:entry1.insert(END,'5'),width=5)
btn.place(x=158,y=110)
btn = Button(window, text="6",command=lambda:entry1.insert(END,'6'),width=5)
btn.place(x=210,y=110)
btn = Button(window, text="-",command=lambda:entry1.insert(END,'-'),width=5,bg='gray',fg='white')
btn.place(x=262,y=110)
btn = Button(window, text="1",command=lambda:entry1.insert(END,'1'),width=5)
btn.place(x=105,y=140)
btn = Button(window, text="2",command=lambda:entry1.insert(END,'2'),width=5)
btn.place(x=158,y=140)
btn = Button(window, text="3",command=lambda:entry1.insert(END,'3'),width=5)
btn.place(x=210,y=140)
btn = Button(window, text="+",command=lambda:entry1.insert(END,'+'),width=5,bg='gray',fg='white')
btn.place(x=262,y=140)
btn = Button(window, text="0",command=lambda:entry1.insert(END,'0'),width=12)
btn.place(x=105,y=170)
btn = Button(window, text=".",command=lambda:entry1.insert(END,'.'),width=5)
btn.place(x=210,y=170)
btn = Button(window, text="=",command=repeat,width=5,bg='gray',fg='white')
btn.place(x=262,y=170)










window.mainloop()
