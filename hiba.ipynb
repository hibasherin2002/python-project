# %%
c=input('enter the name of the first player:')
j=input('enter the name of the secont player:')
while True:
    import random
    a=[c,j]
    b=random.choice(a)
    current_player=b


    d={7:' ',8:' ',9:' ',
       4:' ',5:' ',6:' ',
       1:' ',2:' ',3:' '}



    dic={c:'O',j:'X'}

    def board(d):
        print(f'{d[7]}  |  {d[8]}  |  {d[9]}')
        print('----------------')
        print(f'{d[4]}  |  {d[5]}  |  {d[6]}')
        print('----------------')
        print(f'{d[1]}  |  {d[2]}  |  {d[3]}')


    def number():
        global s
        while True:
            s=input('enter the number bitween 1 or 9:')
            if s=='1'or s=='2'or s=='3'or s=='4'or s=='5'or s=='6'or s=='7'or s=='8'or s=='9':
                s=int(s)
                if d[s]=='X'or d[s]=='O':
                    pass
                else:
                    break
            else:
                pass

    def current1():
        global current_player
        if current_player==c:
            current_player=jy
        else:
            current_player=c

    def board1():
        if current_player==c:
            d[s]=dic[c]
        else:
            d[s]=dic[j]



    def checking(d):
        global gameover
        gameover=False
        if d[7]==d[8]==d[9]=='X'or d[7]==d[8]==d[9]=='O':
            print('winner',b)
            gameover=True
        elif d[4]==d[5]==d[6]=='X'or d[4]==d[5]==d[6]=='O':
            print('winner',b)
            gameover=True
        elif d[1]==d[2]==d[3]=='X'or d[1]==d[2]==d[3]=='O':
            print('winner',b)
            gameover=True
        elif d[1]==d[5]==d[9]=='X'or d[1]==d[5]==d[9]=='O':
            print('winner',b)
            gameover=True
        elif d[7]==d[5]==d[1]=='X'or d[7]==d[5]==d[1]=='O':
            print('winner',b)
            gameover=True
        elif d[8]==d[5]==d[2]=='X'or d[8]==d[5]==d[2]=='O':
            print('winner',b)
            gameover=True
        elif d[9]==d[6]==d[3]=='X'or d[9]==d[6]==d[3]=='O':
            print('winner',b)
            gameover=True
        elif d[7]==d[8]==d[9]=='X'or d[7]==d[8]==d[9]=='O':
            print('winner',b)
            gameover=True
        elif (d[1]=='X'or d[1]=='O')and(d[2]=='X'or d[2]=='O')and(d[3]=='X'or d[3]=='O')and(d[4]=='X'or d[4]=='O')and(d[5]=='X'or d[5]=='O')and(d[6]=='X'or d[6]=='O')and(d[7]=='X'or d[7]=='O')and(d[8]=='X'or d[8]=='O')and(d[9]=='X'or d[9]=='O'):
            print('tie')
            gameover=True
        else:
            return


    number()
    board1()
    board(d)

    while True:
        current1()
        print()
        print()
        number()
        print()
        board1()
        board(d)
        checking(d)
        if gameover==True:
            print()
            print('play again')
            print()
            break
