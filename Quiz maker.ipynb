# %%
from tkinter import *
from tkinter.ttk import *


window = Tk()
window.title("quiz")
window.geometry('500x800')



entry1= Entry(window,width=33)

entry1.place(x=577,y=400)
   

radio = StringVar()
Label(text="1 Grand Central Terminal, Park Avenue, New York is the world's", font=('Aerial 11')).pack()

r1 = Radiobutton(window, text="A-largest railway station", variable=radio, value="A-largest railway station")

r1.pack()
r2 = Radiobutton(window, text="B-highest railway station", variable=radio, value="B-highest railway station")

r2.pack()
r3 = Radiobutton(window, text="C-highest railway station", variable=radio, value="C-highest railway station")

r3.pack()
r4 = Radiobutton(window, text="D-none of the above", variable=radio, value="D-none of the above")
r4.pack()

label = Label(window)
label.pack()


        
radio1 = StringVar()
print()
Label(text='2 Entomology is the science that studies', font=('Aerial 11')).pack()

r1 = Radiobutton(window, text="A-Behavior of human beings", variable=radio1, value="A-Behavior of human beings")

r1.pack()
r2 = Radiobutton(window, text="B-Insects", variable=radio1, value="B-Insects")

r2.pack()
r3 = Radiobutton(window, text="C-The origin and history of technical and scientific terms", variable=radio1, value="C-The origin and history of technical and scientific terms")

r3.pack()
r4 = Radiobutton(window, text="D-The formation of rocks", variable=radio1, value="D-The formation of rocks")
r4.pack()

label = Label(window)
label.pack()



radio2 = StringVar()
Label(text='3 The Rig Veda is divided into ______ books or mandalas ?', font=('Aerial 11')).pack()

r1 = Radiobutton(window, text="A-10", variable=radio2, value="A-10")

r1.pack()
r2 = Radiobutton(window, text="B-8", variable=radio2, value="B-8" )

r2.pack()
r3 = Radiobutton(window, text="C-3", variable=radio2, value="C-3")

r3.pack()
r4 = Radiobutton(window, text="D-6", variable=radio2, value="D-6")
r4.pack()

label = Label(window)
label.pack()


d={1:'A-largest railway station',2:'B-Insects',3:'A-10'}


def score():
    count=0
    if d[1]==radio.get():
        count+=1
    if d[2]==radio1.get():
        count+=1
    if d[3]==radio2.get():
        count+=1
    entry1.insert(END,count)
    btn.config(state='disabled')

    
btn = Button(window, text="score",command=score)
btn.pack()  

def clicked():

    label.configure(text=d[1])

btn = Button(window, text="view answer", command=clicked)

btn.place(x=577,y=450)




window.mainloop()
