# %%
c=input('enter the name:')
j='computer'
global total
global total1
def choose1():
    import random
    a=[c,j]
    b=random.choice(a)
    current_player=b


def toss():
    global f
    global n
    y=['head','tail']
    f=input('enter head or tail:')
    import random
    n=random.choice(y)
    print(n)


def bat():
    global z
    global bb
    global kk
    if f==n:
        z=input('choose bat or ball:')
        if z=='bat':
            print(c,'choose bat first')
        else:
            print(j,'choose bat first')    
    else: 
        import random
        bb=['bat','ball']
        kk=random.choice(bb)
        print('computer has',kk,'first')
               
def newfn():
    global z
    global kk
    if z=='bat' or kk=='ball':
        kk='bat'
        playc1()
    elif kk=='bat' or z=='ball':
        z='bat'
        play1()
    else:
        pass




def checkc():
    global e
    import random
    d=[0,1,2,3,4,5,6]
    e=random.choice(d)
    print('computer:',e)


def check():
    while True:
        global s
        s=input('enter the number between 0 to 6: ')
        if s=='0' or s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6':
            s=int(s)
            print('player:',s)
            return s
        else:
            print('plz enter the number 0 to 6:')







def play():
    global total
    total=0
    global s
    global kk
    global z
    while z=='bat':
        kk='ball'
        s=input('enter the number between 0 to 6: ')
        if s=='0' or s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6':
            s=int(s)
            print('player:',s)
            checkc()
            total=total+s
            if e==s:
                print('OUT')
                print('the final score of',c,'is',total-s)
                break
            else:
                print('the current score of',c,'is',total)
        else:
            pass




def playc():
    global total1
    global e
    global z
    global kk
    total1=0
    global total
    while kk=='bat':
        z='ball'
        check()
        checkc()
        total1=total1+e
        if e==s:
            print('OUT')
            print('the final score of computer',total1-e)
            break
        else:
            print('the current score of computer',total1)
    else:
        pass




def scrc():
    global z
    global kk
    if f==n:
        if z=='bat':
            play()
        else:
            kk='bat'
            playc()
        
    else:
        if kk=='bat':
            playc()
        else:
            z='bat'
            play()
            


def scrc1():
    total1=0
    global z
    global bb
    if f!=n:
        if z=='bat':
            play()
        else:
            playc()
    else:
        bb!=kk
        if kk=='bat':
            playc() 
        else:
            play()

    
def newfn2():
    global total
    global total1
    while total>total1:
        print(c,'won')
        break
    else:
        pass
    
def newfn3(): 
    global total
    global total1
    while total1>total:
        print('computer won')
        break
    else:
        pass
        
    
def play1():
    global total
    total=0
    global s
    global kk
    global z
    while z=='bat':
        kk='ball'
        s=input('enter the number between 0 to 6: ')
        if s=='0' or s=='1' or s=='2' or s=='3' or s=='4' or s=='5' or s=='6':
            s=int(s)
            print('player:',s)
            checkc()
            total=total+s
            if e==s:
                print('OUT')
                print('the final score of',c,'is',total-s)
                newfn3()
                break
            else:
                print('the current score of',c,'is',total)
                newfn2()
        else:
            pass


def playc1():
    global e
    global z
    global kk
    global total1
    total1=0
    while kk=='bat':
        z='ball'
        check()
        checkc()
        total1=total1+e
        if e==s:
            print('OUT')
            print('the final score of computer',total1-e)
            newfn2()
            break
        else:
            print('the current score of computer',total1)
            newfn3()
    else:
        pass


choose1()
toss()
bat()
scrc()
print()
print('second batting')
print()
newfn()
# Out:
# enter the name:h
# enter head or tail:4
# head
# computer has bat first
# enter the number between 0 to 6: 5
# player: 5
# computer: 6
# the current score of computer 6
# enter the number between 0 to 6: 5
# player: 5
# computer: 1
# the current score of computer 7
# enter the number between 0 to 6: 5
# player: 5
# computer: 4
# the current score of computer 11
# enter the number between 0 to 6: 5
# player: 5
# computer: 1
# the current score of computer 12
# enter the number between 0 to 6: 5
# player: 5
# computer: 4
# the current score of computer 16
# enter the number between 0 to 6: 5
# player: 5
# computer: 6
# the current score of computer 22
# enter the number between 0 to 6: 5
# player: 5
# computer: 3
# the current score of computer 25
# enter the number between 0 to 6: 5
# player: 5
# computer: 1
# the current score of computer 26
# enter the number between 0 to 6: 5
# player: 5
# computer: 1
# the current score of computer 27
# enter the number between 0 to 6: 5
# ...

# %%
if batting=='second'
    if total>total1:
        print('computer won')
        break
